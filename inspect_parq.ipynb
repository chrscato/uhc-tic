# %% [markdown]
# --inspect parquet output folder

# %%
#!/usr/bin/env python3
"""Inspect Parquet files from TiC MRF processing."""

import pandas as pd
import pyarrow.parquet as pq
from pathlib import Path
import numpy as np

def inspect_parquet_file(file_path):
    """Comprehensive inspection of a Parquet file."""
    
    print(f"🔍 Inspecting: {file_path}")
    print("=" * 60)
    
    # Basic file info
    file_size = Path(file_path).stat().st_size
    print(f"File size: {file_size / 1024 / 1024:.2f} MB")
    
    # Read with PyArrow for schema info
    parquet_file = pq.ParquetFile(file_path)
    print(f"Schema:")
    print(parquet_file.schema)
    print()
    
    # Read with Pandas for analysis
    df = pd.read_parquet(file_path)
    
    # Basic stats
    print(f"📊 Basic Statistics:")
    print(f"Total records: {len(df):,}")
    print(f"Columns: {len(df.columns)}")
    print(f"Memory usage: {df.memory_usage(deep=True).sum() / 1024 / 1024:.2f} MB")
    print()
    
    # Column info
    print(f"📋 Column Details:")
    for col in df.columns:
        dtype = df[col].dtype
        null_count = df[col].isnull().sum()
        
        # Handle list/array columns safely
        try:
            # Check if column contains lists/arrays
            sample_val = df[col].dropna().iloc[0] if len(df[col].dropna()) > 0 else None
            if isinstance(sample_val, (list, tuple)) or (hasattr(sample_val, 'dtype') and 'int' in str(sample_val.dtype)):
                unique_count = "list/array"
            else:
                unique_count = df[col].nunique() if len(df) < 10000 else "many"
        except:
            unique_count = "complex"
            
        print(f"  {col:20} | {str(dtype):15} | {null_count:6} nulls | {unique_count} unique")
    print()
    
    # Service code analysis
    if 'service_code' in df.columns:
        print(f"🏥 Service Code Analysis:")
        code_counts = df['service_code'].value_counts()
        print(f"Unique service codes: {len(code_counts)}")
        print("Top codes by frequency:")
        for code, count in code_counts.head(10).items():
            print(f"  {code}: {count:,} records")
        print()
    
    # Rate analysis
    if 'negotiated_rate' in df.columns:
        rates = df['negotiated_rate']
        print(f"💰 Rate Analysis:")
        print(f"Rate range: ${rates.min():.2f} - ${rates.max():.2f}")
        print(f"Average rate: ${rates.mean():.2f}")
        print(f"Median rate: ${rates.median():.2f}")
        print(f"Standard deviation: ${rates.std():.2f}")
        
        # Rate percentiles
        print(f"Rate percentiles:")
        for p in [10, 25, 50, 75, 90, 95, 99]:
            print(f"  {p:2d}th percentile: ${rates.quantile(p/100):.2f}")
        print()
    
    # Provider analysis
    if 'provider_tin' in df.columns:
        tin_counts = df['provider_tin'].value_counts()
        print(f"🏢 Provider Analysis:")
        print(f"Unique TINs: {len(tin_counts)}")
        print("Top TINs by record count:")
        for tin, count in tin_counts.head(5).items():
            print(f"  {tin}: {count:,} records")
        print()
    
    # Payer analysis
    if 'payer' in df.columns:
        payer_counts = df['payer'].value_counts()
        print(f"🏥 Payer Analysis:")
        for payer, count in payer_counts.items():
            print(f"  {payer}: {count:,} records")
        print()
    
    # Sample records
    print(f"📄 Sample Records (first 5):")
    # Show key columns only for readability
    key_cols = ['service_code', 'negotiated_rate', 'billing_code_type', 'provider_tin', 'payer']
    available_cols = [col for col in key_cols if col in df.columns]
    print(df[available_cols].head())
    print()
    
    # Rate distribution by service code
    if 'service_code' in df.columns and 'negotiated_rate' in df.columns:
        print(f"💲 Rate Distribution by Service Code:")
        rate_stats = df.groupby('service_code')['negotiated_rate'].agg(['count', 'min', 'max', 'mean', 'std']).round(2)
        print(rate_stats)
        print()
    
    return df

def inspect_all_parquet_files(directory="output"):
    """Inspect all Parquet files in a directory."""
    
    parquet_files = list(Path(directory).glob("*.parquet"))
    
    if not parquet_files:
        print(f"No Parquet files found in {directory}/")
        return
    
    print(f"Found {len(parquet_files)} Parquet file(s) in {directory}/")
    print()
    
    for file_path in parquet_files:
        inspect_parquet_file(file_path)
        print("\n" + "="*80 + "\n")

if __name__ == "__main__":
    # Inspect all files in output directory
    inspect_all_parquet_files("output")
    
    # Or inspect a specific file
    # inspect_parquet_file("output/centene_fidelis_rates.parquet")
# Out:
# Found 3 Parquet file(s) in output/
#
# 🔍 Inspecting: output\centene_fidelis_rates.parquet
# ============================================================
# File size: 0.07 MB
# Schema:
# <pyarrow._parquet.ParquetSchema object at 0x000001F395C5D880>
# required group field_id=-1 schema {
#   optional binary field_id=-1 service_code (String);
#   optional binary field_id=-1 billing_code_type (String);
#   optional binary field_id=-1 description (String);
#   optional double field_id=-1 negotiated_rate;
#   optional group field_id=-1 service_codes (List) {
#     repeated group field_id=-1 list {
#       optional binary field_id=-1 element (String);
#     }
#   }
#   optional binary field_id=-1 billing_class (String);
#   optional binary field_id=-1 negotiated_type (String);
#   optional binary field_id=-1 expiration_date (String);
#   optional group field_id=-1 provider_npi (List) {
#     repeated group field_id=-1 list {
#       optional int64 field_id=-1 element;
#     }
#   }
#   optional int32 field_id=-1 provider_name (Null);
#   optional binary field_id=-1 provider_tin (String);
#   optional binary field_id=-1 payer (String);
# }
#
#
# 📊 Basic Statistics:
# Total records: 1,000
# Columns: 12
# Memory usage: 0.79 MB
#
# 📋 Column Details:
#   service_code         | object          |      0 nulls | 8 unique
#   billing_code_type    | object          |      0 nulls | 2 unique
#   description          | object          |      0 nulls | 8 unique
#   negotiated_rate      | float64         |      0 nulls | 61 unique
#   service_codes        | object          |      0 nulls | complex unique
#   billing_class        | object          |      0 nulls | 1 unique
#   negotiated_type      | object          |      0 nulls | 1 unique
#   expiration_date      | object          |      0 nulls | 1 unique
#   provider_npi         | object          |      0 nulls | list/array unique
#   provider_name        | object          |   1000 nulls | 0 unique
#   provider_tin         | object          |      0 nulls | 900 unique
#   payer                | object          |      0 nulls | 1 unique
#
# 🏥 Service Code Analysis:
# Unique service codes: 8
# Top codes by frequency:
#   99213: 957 records
#   0241U: 28 records
#   72148: 6 records
#   10005: 3 records
#   10006: 3 records
#   0240U: 1 records
#   70450: 1 records
#   10040: 1 records
#
# 💰 Rate Analysis:
# Rate range: $41.76 - $456.00
# Average rate: $62.11
# Median rate: $51.45
# Standard deviation: $37.10
# Rate percentiles:
#   10th percentile: $50.40
#   25th percentile: $51.45
#   50th percentile: $51.45
#   75th percentile: $51.45
#   90th percentile: $100.30
#   95th percentile: $107.33
#   99th percentile: $212.54
#
# 🏢 Provider Analysis:
# Unique TINs: 900
# Top TINs by record count:
#   133544120: 10 records
#   272872791: 5 records
#   113322995: 5 records
#   471758444: 4 records
#   135562308: 4 records
#
# 🏥 Payer Analysis:
#   centene_fidelis: 1,000 records
#
# 📄 Sample Records (first 5):
#   service_code  negotiated_rate billing_code_type provider_tin  \
# 0        0240U           121.23             HCPCS    133544120
# 1        0241U           249.62             HCPCS    133544120
# 2        0241U           192.55             HCPCS    471758444
# 3        0241U           192.55             HCPCS    474539584
# 4        0241U           192.55             HCPCS    923278147
#
#              payer
# 0  centene_fidelis
# 1  centene_fidelis
# 2  centene_fidelis
# 3  centene_fidelis
# 4  centene_fidelis
#
# 💲 Rate Distribution by Service Code:
#               count     min     max    mean    std
# service_code
# 0240U             1  121.23  121.23  121.23    NaN
# 0241U            28   76.31  297.52  173.54  59.94
# 10005             3  152.18  152.18  152.18   0.00
# 10006             3   67.80   67.80   67.80   0.00
# 10040             1  116.96  116.96  116.96    NaN
# 70450             1   41.76   41.76   41.76    NaN
# 72148             6  199.72  334.60  227.90  52.60
# 99213           957   45.00  456.00   57.41  27.05
#
#
# ================================================================================
#
# 🔍 Inspecting: output\centene_fidelis_rates_0001.parquet
# ============================================================
# File size: 0.06 MB
# Schema:
# <pyarrow._parquet.ParquetSchema object at 0x000001F395D14140>
# required group field_id=-1 schema {
#   optional binary field_id=-1 service_code (String);
#   optional binary field_id=-1 billing_code_type (String);
#   optional binary field_id=-1 description (String);
#   optional double field_id=-1 negotiated_rate;
#   optional group field_id=-1 service_codes (List) {
#     repeated group field_id=-1 list {
#       optional binary field_id=-1 element (String);
#     }
#   }
#   optional binary field_id=-1 billing_class (String);
#   optional binary field_id=-1 negotiated_type (String);
#   optional binary field_id=-1 expiration_date (String);
#   optional group field_id=-1 provider_npi (List) {
#     repeated group field_id=-1 list {
#       optional int64 field_id=-1 element;
#     }
#   }
#   optional int32 field_id=-1 provider_name (Null);
#   optional binary field_id=-1 provider_tin (String);
#   optional binary field_id=-1 payer (String);
# }
#
#
# 📊 Basic Statistics:
# Total records: 1,000
# Columns: 12
# Memory usage: 0.79 MB
#
# 📋 Column Details:
#   service_code         | object          |      0 nulls | 2 unique
#   billing_code_type    | object          |      0 nulls | 1 unique
#   description          | object          |      0 nulls | 1 unique
#   negotiated_rate      | float64         |      0 nulls | 63 unique
#   service_codes        | object          |      0 nulls | complex unique
#   billing_class        | object          |      0 nulls | 1 unique
#   negotiated_type      | object          |      0 nulls | 1 unique
#   expiration_date      | object          |      0 nulls | 1 unique
#   provider_npi         | object          |      0 nulls | list/array unique
#   provider_name        | object          |   1000 nulls | 0 unique
#   provider_tin         | object          |      0 nulls | 692 unique
#   payer                | object          |      0 nulls | 1 unique
#
# 🏥 Service Code Analysis:
# Unique service codes: 2
# Top codes by frequency:
#   99214: 607 records
#   99213: 393 records
#
# 💰 Rate Analysis:
# Rate range: $45.00 - $456.00
# Average rate: $73.55
# Median rate: $70.35
# Standard deviation: $33.18
# Rate percentiles:
#   10th percentile: $51.45
#   25th percentile: $51.45
#   50th percentile: $70.35
#   75th percentile: $74.55
#   90th percentile: $101.06
#   95th percentile: $128.56
#   99th percentile: $196.13
#
# 🏢 Provider Analysis:
# Unique TINs: 692
# Top TINs by record count:
#   61242656: 7 records
#   135562308: 6 records
#   453023019: 5 records
#   861058656: 5 records
#   113489344: 4 records
#
# 🏥 Payer Analysis:
#   centene_fidelis: 1,000 records
#
# 📄 Sample Records (first 5):
#   service_code  negotiated_rate billing_code_type provider_tin  \
# 0        99213            51.45               CPT    101645875
# 1        99213            51.45               CPT    132663328
# 2        99213            51.45               CPT    263381883
# 3        99213            51.45               CPT    111874531
# 4        99213            51.45               CPT    220354790
#
#              payer
# 0  centene_fidelis
# 1  centene_fidelis
# 2  centene_fidelis
# 3  centene_fidelis
# 4  centene_fidelis
#
# 💲 Rate Distribution by Service Code:
#               count    min     max   mean    std
# service_code
# 99213           393  45.00  149.89  60.75  21.12
# 99214           607  70.35  456.00  81.84  36.76
#
#
# ================================================================================
#
# 🔍 Inspecting: output\centene_fidelis_rates_0002.parquet
# ============================================================
# File size: 0.07 MB
# Schema:
# <pyarrow._parquet.ParquetSchema object at 0x000001F39463A5C0>
# required group field_id=-1 schema {
#   optional binary field_id=-1 service_code (String);
#   optional binary field_id=-1 billing_code_type (String);
#   optional binary field_id=-1 description (String);
#   optional double field_id=-1 negotiated_rate;
#   optional group field_id=-1 service_codes (List) {
#     repeated group field_id=-1 list {
#       optional binary field_id=-1 element (String);
#     }
#   }
#   optional binary field_id=-1 billing_class (String);
#   optional binary field_id=-1 negotiated_type (String);
#   optional binary field_id=-1 expiration_date (String);
#   optional group field_id=-1 provider_npi (List) {
#     repeated group field_id=-1 list {
#       optional int64 field_id=-1 element;
#     }
#   }
#   optional int32 field_id=-1 provider_name (Null);
#   optional binary field_id=-1 provider_tin (String);
#   optional binary field_id=-1 payer (String);
# }
#
#
# 📊 Basic Statistics:
# Total records: 924
# Columns: 12
# Memory usage: 0.73 MB
#
# 📋 Column Details:
#   service_code         | object          |      0 nulls | 2 unique
#   billing_code_type    | object          |      0 nulls | 1 unique
#   description          | object          |      0 nulls | 1 unique
#   negotiated_rate      | float64         |      0 nulls | 37 unique
#   service_codes        | object          |      0 nulls | complex unique
#   billing_class        | object          |      0 nulls | 1 unique
#   negotiated_type      | object          |      0 nulls | 1 unique
#   expiration_date      | object          |      0 nulls | 1 unique
#   provider_npi         | object          |      0 nulls | list/array unique
#   provider_name        | object          |    924 nulls | 0 unique
#   provider_tin         | object          |      0 nulls | 475 unique
#   payer                | object          |      0 nulls | 1 unique
#
# 🏥 Service Code Analysis:
# Unique service codes: 2
# Top codes by frequency:
#   99214: 818 records
#   99215: 106 records
#
# 💰 Rate Analysis:
# Rate range: $70.35 - $456.00
# Average rate: $96.08
# Median rate: $74.55
# Standard deviation: $50.87
# Rate percentiles:
#   10th percentile: $70.35
#   25th percentile: $70.35
#   50th percentile: $74.55
#   75th percentile: $74.55
#   90th percentile: $171.58
#   95th percentile: $218.37
#   99th percentile: $256.38
#
# 🏢 Provider Analysis:
# Unique TINs: 475
# Top TINs by record count:
#   135562308: 8 records
#   61242656: 7 records
#   133237927: 6 records
#   133375559: 6 records
#   133346908: 5 records
#
# 🏥 Payer Analysis:
#   centene_fidelis: 924 records
#
# 📄 Sample Records (first 5):
#   service_code  negotiated_rate billing_code_type provider_tin  \
# 0        99214            70.35               CPT    132620896
# 1        99214            70.35               CPT    132608325
# 2        99214            70.35               CPT    201480790
# 3        99214            70.35               CPT    132828349
# 4        99214            70.35               CPT    264295078
#
#              payer
# 0  centene_fidelis
# 1  centene_fidelis
# 2  centene_fidelis
# 3  centene_fidelis
# 4  centene_fidelis
#
# 💲 Rate Distribution by Service Code:
#               count    min     max    mean    std
# service_code
# 99214           818  70.35  208.01   81.31  23.74
# 99215           106  97.65  456.00  210.03  59.62
#
#
# ================================================================================
